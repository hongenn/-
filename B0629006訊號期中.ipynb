# %%
dataframe=pd.read_csv("https://query1.finance.yahoo.com/v7/finance/download/%5EGSPC?period1=-1325635200&period2=1588550400&interval=1d&events=history")

# %%
class Hn():
    def evalute():
        t = np.linspace(0, 10, 5001)
        w = chirp(t, f0=6, f1=1, t1=10, method='linear')
        plt.plot(t, w)
        plt.title("Linear Chirp, f(0)=6, f(10)=1")
        plt.xlabel('t (sec)')
        plt.show()

# %%
t = np.linspace(0, 10, 5001)
w = chirp(t, f0=6, f1=1, t1=10, method='linear')
plt.plot(t, w)
plt.title("Linear Chirp, f(0)=6, f(10)=1")
plt.xlabel('t (sec)')
plt.show()

# %%
t = np.linspace(0, 10, 5001)
w = chirp(t, f0=0.22, f1=0.44, t1=10, method='linear')
plt.plot(t, w)
plt.title("Linear Chirp, f(0)=0.22, f(10)=0.44")
plt.xlabel('t (sec)')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import thinkdsp as tp
from scipy.signal import chirp, spectrogram

# %%
dataframe=pd.read_csv("https://query1.finance.yahoo.com/v7/finance/download/%5EGSPC?period1=-1325635200&period2=1588550400&interval=1d&events=history")

# %%
print(dataframe[:5],"\n")

print(dataframe[-5:])
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  1927-12-30  17.660000  17.660000  17.660000  17.660000  17.660000       0
# 1  1928-01-03  17.760000  17.760000  17.760000  17.760000  17.760000       0
# 2  1928-01-04  17.719999  17.719999  17.719999  17.719999  17.719999       0
# 3  1928-01-05  17.549999  17.549999  17.549999  17.549999  17.549999       0
# 4  1928-01-06  17.660000  17.660000  17.660000  17.660000  17.660000       0
#
#              Date         Open         High          Low        Close  \
# 23188  2020-04-27  2854.649902  2887.719971  2852.889893  2878.479980
# 23189  2020-04-28  2909.959961  2921.149902  2860.709961  2863.389893
# 23190  2020-04-29  2918.459961  2954.860107  2912.159912  2939.510010
# 23191  2020-04-30  2930.909912  2930.909912  2892.469971  2912.429932
# 23192  2020-05-01  2869.090088  2869.090088  2821.610107  2830.709961
#
#          Adj Close      Volume
# 23188  2878.479980  5194260000
# ...

# %%
ys=dataframe['Close'].values

# %%
plt.plot(np.arange(len(ys)),ys)

# %%
plt.plot(np.arange(len(ys[-5000:])),ys[-5000:])

# %%
yWave= thinkdsp.Wave(ys, framerate= 10000)
yWave.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-a51d92cea6a2> in <module>
# ----> 1 yWave= thinkdsp.Wave(ys, framerate= 10000)
#       2 yWave.plot()
#
# NameError: name 'thinkdsp' is not defined

# %%
yWave.make_spectrum().make_integrated_spectrum().plot_power()
plt.xscale('log')
plt.yscale('log')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-501429425ed5> in <module>
# ----> 1 yWave.make_spectrum().make_integrated_spectrum().plot_power()
#       2 plt.xscale('log')
#       3 plt.yscale('log')
#
# NameError: name 'yWave' is not defined

# %%
signal = thinkdsp.UncorrelatedUniformNoise()
x = signal.make_wave(duration=1, framerate=10000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-6ddb9a204bef> in <module>
# ----> 1 signal = thinkdsp.UncorrelatedUniformNoise()
#       2 x = signal.make_wave(duration=1, framerate=10000)
#
# NameError: name 'thinkdsp' is not defined

# %%
x.ys.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-1439540f7ef5> in <module>
# ----> 1 x.ys.shape
#
# NameError: name 'x' is not defined

# %%
from thinkdsp import UncorrelatedGaussianNoise

signal = UncorrelatedGaussianNoise()
x = signal.make_wave(duration=0.5, framerate=11025)
x.plot(linewidth=0.5)
x.ys.max(), x.ys.mean(), x.ys.std()
# Out:
# (3.2294634985259982, 0.0018783551916262192, 1.017989478226139)

# %%
spectrum = x.make_spectrum()
spectrum.plot_power(linewidth=1)

# %%
integ = spectrum.make_integrated_spectrum()
integ.plot_power()

# %%
integ = spectrum.make_integrated_spectrum()
integ.plot_power()

# %%
integ = spectrum.make_integrated_spectrum()
integ.plot_power()

# %%
y= thinkdsp.UncorrelatedGaussianNoise()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-83f005c5b9fd> in <module>
# ----> 1 y= thinkdsp.UncorrelatedGaussianNoise()
#
# NameError: name 'thinkdsp' is not defined

# %%
x= thinkdsp.UncorrelatedGaussianNoise()
x= x.make_wave(duration= 1, framerate= 10000)

y= x.cumsum()
x.ys.shape, y.ys.shape
y.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-d1c206548e27> in <module>
# ----> 1 x= thinkdsp.UncorrelatedGaussianNoise()
#       2 x= x.make_wave(duration= 1, framerate= 10000)
#       3
#       4 y= x.cumsum()
#       5 x.ys.shape, y.ys.shape
#
# NameError: name 'thinkdsp' is not defined

# %%
plt.plot(x.ts, x.ys)

# %%
z= thinkdsp.BrownianNoise().make_wave(duration=1, framerate=10000)
z.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-0d4844e9779a> in <module>
# ----> 1 z= thinkdsp.BrownianNoise().make_wave(duration=1, framerate=10000)
#       2 z.plot()
#
# NameError: name 'thinkdsp' is not defined

# %%
z= td.BrownianNoise().make_wave(duration=1, framerate=10000)
z.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-88b4994345c8> in <module>
# ----> 1 z= td.BrownianNoise().make_wave(duration=1, framerate=10000)
#       2 z.plot()
#
# NameError: name 'td' is not defined

# %%
z.make_spectrum().make_integrated_spectrum().estimate_slope()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-82fa107f3ce5> in <module>
# ----> 1 z.make_spectrum().make_integrated_spectrum().estimate_slope()
#
# NameError: name 'z' is not defined
